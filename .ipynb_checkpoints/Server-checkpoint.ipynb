# %%
import json
import numpy as np
import os
import pandas as pd
import urllib2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-6929f56e2432> in <module>()
#       3 import os
#       4 import pandas as pd
# ----> 5 import urllib.request
#
# ImportError: No module named request
